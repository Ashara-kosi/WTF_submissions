# %%
def mul_add(a,b): 
   multi = a * b
       While multi <= 100: 
return multi 
   else: 
       return a + b
# Out:
#   File "<ipython-input-1-42a8ad5a8746>", line 3
#     While multi <= 100:
#     ^
# IndentationError: unexpected indent

# %%
#1.	Write a function to calculate the multiplication and sum of two numbers.
def multiplication_sum(x,y):
        print(x * y, x + y)

# %%
multiplication_sum(5,4)
# Out:
# 20 9

# %%
#2.	Write a function to print the sum of the current number and the previous number
def sum_current_previous(x):
    previous = (x - 1)
    print(int(previous + int(x)))

# %%
sum_current_previous(10)
# Out:
# 19

# %%
#3.	Write a function to print characters from a string that are present at an even index number
def character_string():
    A = 'Great'
    B = []
    C = A[0]
    D = A[2]
    E = A[4]
    B.append(C)
    B.append(D)
    B.append(E)
    print(B)

# %%
character_string()
# Out:
# ['G', 'e', 't']

# %%
def char_str(x):
    A = []
    for i in x[0:]:
        A.append(i)
        print(A[0:])

# %%
char_str('great')
# Out:
# ['g']
# ['g', 'r']
# ['g', 'r', 'e']
# ['g', 'r', 'e', 'a']
# ['g', 'r', 'e', 'a', 't']

# %%
def character_string():
    x = 'characteristics'
    i = 0
    print('character present at even index:')
    while i < len(x):
        print(x[i])
        i = i + 2

# %%
character_string()
# Out:
# character present at even index:
# c
# a
# a
# t
# r
# s
# i
# s

# %%
4.#Write a function to remove first characters from a string
def remove_first_char( C = input('What is your name ')):
    print(C.replace(C[0], ''))
# Out:
# What is your name juliet

# %%
remove_first_char()
# Out:
# uliet

# %%
4.#Write a function to remove first characters from a string
def remove_first_char(C):
    print(C.replace(C[0], ''))

# %%
remove_first_char('Juliet')
# Out:
# uliet

# %% [markdown]
# 5.#Write a function to check if the first and last number of a list is the same

# %%
def first_last(list):
    if list[0] == list[-1]:
        print (True)
    else:
         print (False)

# %%
list=[2,4,5,6,8,7,5,45,6]
first_last(list)
# Out:
# False

# %% [markdown]
# #3.	Write a function to print characters from a string that are present at an even index number

# %%
def character_string(x):
    i = 0
    print('character present at even index:')
    while i < len(x):
        print(x[i])
        i = i + 2

# %%
character_string()
x= "characteristics"
# Out:
# character present at even index:
# c
# a
# a
# t
# r
# s
# i
# s

# %% [markdown]
#  6. Write a function to print multiplication table from 1 to 10

# %%
def mult_table(number):
    for i in range (1,13):
        multiply = number*i
        table = str(number) + ' x ' + str(i) + ' = ' + str(multiply)
        print (table)
    
    return

# %%
mult_table(2)
# Out:
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
# 2 x 10 = 20
# 2 x 11 = 22
# 2 x 12 = 24

# %%
def mult_table(x):
    while i in range(1,13):
        print (x*=i)
    x=x+1
# Out:
#   File "C:\Users\DELL\AppData\Local\Temp/ipykernel_4368/1968250587.py", line 3
#     print (x*=i)
#             ^
# SyntaxError: invalid syntax

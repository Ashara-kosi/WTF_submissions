# %%
def sum(Limit):

  summ=0
  for i in range(Limit+1):
      if (i % 3 ==0):
        summ= summ+(i)
      if ( i % 5 ==0):
       summ= summ+(i)
  print("The sum is equal to:", summ)
 


num = int(input("Enter a number: "))
sum(num)
# Out:
# Enter a number: 5
# The sum is equal to: 8

# %%
def shownumbers(Limit):


for i in range(Limit):
    mod = Limit % 2
    if mod > 0:
         print(Limit, "ODD")
    else:
         print(Limit, "EVEN")
    Limit=Limit-1



num = int(input("Enter a number: "))
shownumbers(num)
print(0, "EVEN")
